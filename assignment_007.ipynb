# %% [markdown]
# MATHPLOTLIB FUNCTIONS

# %%
#line graph
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.title('Sample Plot')
plt.ylabel('Values')
plt.xlabel('Index')
plt.plot(x, y)
plt.show()
